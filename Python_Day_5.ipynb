# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("database.csv")
# df.plot(kind='scatter', x = "Perpetrator Count", y = "Victim Count")
# plt.show()
weaponcount = df["Weapon"].value_counts(dropna = False).tolist()
solvedcount = df["Crime Solved"].value_counts(dropna = False).tolist()
print(solvedcount)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# [448172, 190282]

# %%
print(df["Weapon"].value_counts(dropna = False))
# Out:
# Handgun          317484
# Knife             94962
# Blunt Object      67337
# Firearm           46980
# Unknown           33192
# Shotgun           30722
# Rifle             23347
# Strangulation      8110
# Fire               6173
# Suffocation        3968
# Gun                2206
# Drugs              1588
# Drowning           1204
# Explosives          537
# Poison              454
# Fall                190
# Name: Weapon, dtype: int64

# %%
handgun_index = df.loc[(df["Weapon"] == "Fall") & (df["Crime Solved"] == "Yes")].index.tolist()
print(len(handgun_index))
# Out:
# 166

# %%
pilist = [166, 24]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with a Fall as the Murder Method")
plt.show()

# %%
pilist = [376, 78]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with Poison as the Murder Weapon")
plt.show()

# %%
pilist = [388, 149]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with Explosives as the Murder Weapon")
plt.show()

# %%
pilist = [999, 205]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with Drowning as the Murder Method")
plt.show()

# %%
pilist = [1396, 192]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with Drugs as the Murder Weapon")
plt.show()

# %%
pilist = [1324, 882]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with a Gun as the Murder Weapon")
plt.show()

# %%
pilist = [2978, 990]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with Suffocation as the Murder Method")
plt.show()

# %%
pilist = [4139, 2034]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with Fire as the Murder Weapon")
plt.show()

# %%
pilist = [4409, 3701]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with Strangulation as the Murder Method")
plt.show()

# %%
pilist = [19946, 3401]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with a Rifle as the Murder Weapons")
plt.show()

# %%
pilist = [26040, 4682]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with a Shotgun as the Murder Weapons")
plt.show()

# %%
pilist = [18409, 14783]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with Unknown Murder Weapons")
plt.show()

# %%
pilist = [24402, 22578]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with Firearms as the Murder Weapon")
plt.show()

# %%
pilist = [51504, 15833]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with Blunt Objects as the Murder Weapon")
plt.show()

# %%
pilist = [216938, 100546]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with Handguns as the Murder Weapon")
plt.show()

# %%
pilist = [74758, 20204]
labels = ["Crimes Solved", "Crimes Unsolved"]

fig = plt.figure()
ax = fig.add_subplot()
ax.pie(pilist, labels = labels, autopct = int, shadow = True, rotatelabels = False)

plt.title("Crimes with Knives as the Murder Weapon")
plt.show()

# %% [markdown]
# Work on finding a correlation between murder weapon and whther the crime gets solved
